# %% [markdown]
# # Movie Analysis and Recommendation
#
# We use the Movie Database API (TMDb), the dataset is requested in another jupyter notebook and is saved in a csv file: https://colab.research.google.com/drive/1sXDBMVWvjf-Fp21KdVKlWuI0NyHszyDe
# ---
#
# ### Essential Libraries
#
# Let us begin by importing the essential Python Libraries.
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ---
#
# # Import the Dataset
#
# The dataset is in CSV format; hence we use the `read_csv` function from Pandas.
# Immediately after importing, take a quick look at the data using the `head` function.

# %%
movies = pd.read_csv('movies.csv', lineterminator='\n') #Used for machine learning. The genres are strings

# %%
movies.head()
# Out:
#       id  movieId  ... vote_average vote_count
# 0    862        1  ...          7.9      13855
# 1   8844        2  ...          7.2       8108
# 2  15602        3  ...          6.5        242
# 3  31357        4  ...          6.4         90
# 4  11862        5  ...          6.2        484
#
# [5 rows x 14 columns]

# %% [markdown]
# Let's check the columns:
#
# > 1. **id**: ID of a movie on TMDB.
# > 2. **movieId**: ID of a movie on MovieLens.
# > 3. **title**: The title of the movie.
# > 4. **genres** : Genres tag of the movie
# > 5. **overview**: A brief introduction of the movie. It is interesting to read.
# > 6. **original_language**: The original language of the movie.
# > 7. **budget** : How much money has been put to make the movie.
# > 8. **popularity**: It shows how popular the movie is.
# > 9. **production_companies**: Which companies produced this movie.
# > 10. **production_countries**: In which the movie is produced.
# > 11. **revenue**: The revenue of the movie.
# > 12. **runtime**: How long the movie is.
# > 13. **vote_average**: The average vote this movie got.
# > 14. **vote_count**: How many people vote for this movie.

# %% [markdown]
# Then we convert the data type into corresponding data type.

# %%
movies['budget'] = movies['budget'].astype('int64')
movies['popularity'] = movies['popularity'].astype('float')
movies['revenue'] = movies['revenue'].astype('int64')
movies['runtime'] = movies['runtime'].astype('int64')
movies['vote_average'] = movies['vote_average'].astype('float')
movies['vote_count'] = movies['vote_count'].astype('int')

# %%
# print the type of each column
movies.dtypes
# Out:
# id                        int64
# movieId                   int64
# title                    object
# genres                   object
# overview                 object
# original_language        object
# budget                    int64
# popularity              float64
# production_companies     object
# production_countries     object
# revenue                   int64
# runtime                   int64
# vote_average            float64
# vote_count                int64
# dtype: object

# %% [markdown]
# ---
#
# # Basic Statistics
#
# Now, we have gotten the data in DataFrame. We'd like to have some basic statistics.

# %%
nums_dtype = pd.DataFrame(movies[['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']])
nums_dtype.describe()
# Out:
#              budget    popularity  ...  vote_average    vote_count
# count  2.671700e+04  26717.000000  ...  26717.000000  26717.000000
# mean   6.460143e+06      7.434112  ...      6.203526    385.796197
# std    2.130586e+07      7.363290  ...      1.182214   1341.140367
# min    0.000000e+00      0.600000  ...      0.000000      0.000000
# 25%    0.000000e+00      3.583000  ...      5.700000     14.000000
# 50%    0.000000e+00      6.085000  ...      6.300000     43.000000
# 75%    9.230000e+05      8.943000  ...      6.900000    172.000000
# max    9.653130e+08    145.168000  ...     10.000000  28829.000000
#
# [8 rows x 6 columns]

# %%
# Set up matplotlib figure with three subplots
f, axes = plt.subplots(6, 3, figsize=(24, 36))
count = 0
for var in nums_dtype:
  sb.boxplot(data = nums_dtype[var], orient = "h", ax = axes[count,0])
  sb.histplot(data = nums_dtype[var], bins = 30, ax = axes[count,1])
  sb.violinplot(data = nums_dtype[var], orient = "h", ax = axes[count,2])
  count += 1

# %% [markdown]
# The data has many interesting deductions:
# - Firstly, we found that some movies (over 25%) have no budget.
# - For the popularity, it is very different among movies. The most popular movie has popularity of 145 while most of the movies (over 75%) have popularity less than 30. (It is not easy to make a popular movie)
# - The revenues distribute not uniformly as well.
# - For the runtime, there are some movie whose runtime is 0 because they are initially a Null value; there are also movies with runtime very high. However, there are many of them have pretty high popularity.
# - The vote average is quite good. There are some movie got 0 which is weird and we will deal with them later. However, except for them, the distribution is almost a bell line.

# %% [markdown]
# After the discussion above, we found some issues in the data. In this data analysis, we want to find the properties of "normal" movies. So we only focus on the movie with a "normal" runtime (within 300 minutes and not equals to 0). First, we'd like to delete movies whose runtime is more than 300 minutes.

# %%
#delete the rows whose runtime is 0.
movies = movies.drop(movies[movies['runtime']>300].index)
movies = movies.drop(movies[movies['runtime'] == 0].index)
print(movies.dtypes)
print(movies.shape)
# Out:
# id                        int64
# movieId                   int64
# title                    object
# genres                   object
# overview                 object
# original_language        object
# budget                    int64
# popularity              float64
# production_companies     object
# production_countries     object
# revenue                   int64
# runtime                   int64
# vote_average            float64
# vote_count                int64
# dtype: object
# (26513, 14)

# %%
# Extract only the numeric data variables
nums_dtype = pd.DataFrame(movies[["budget", "popularity", "revenue", "runtime", "vote_average", "vote_count"]])

# Summary Statistics for all Variables
nums_dtype.describe()
# Out:
#              budget    popularity  ...  vote_average    vote_count
# count  2.651300e+04  26513.000000  ...  26513.000000  26513.000000
# mean   6.504225e+06      7.470407  ...      6.209263    388.607966
# std    2.137253e+07      7.376885  ...      1.166381   1345.897918
# min    0.000000e+00      0.600000  ...      0.000000      0.000000
# 25%    0.000000e+00      3.624000  ...      5.700000     14.000000
# 50%    0.000000e+00      6.116000  ...      6.400000     44.000000
# 75%    1.000000e+06      8.964000  ...      6.900000    175.000000
# max    9.653130e+08    145.168000  ...     10.000000  28829.000000
#
# [8 rows x 6 columns]

# %%
# Set up matplotlib figure with three subplots
f, axes = plt.subplots(6, 3, figsize=(24, 36))
count = 0
for var in nums_dtype:
  sb.boxplot(data = movies[var], orient = "h", ax = axes[count,0])
  sb.histplot(data = movies[var], bins = 30, ax = axes[count,1])
  sb.violinplot(data = movies[var], orient = "h", ax = axes[count,2])
  count += 1

# %%
#find out how many 0 are there in each variable.
(nums_dtype.T == 0).astype(int).sum(axis=1)
# Out:
# budget          18727
# popularity          0
# revenue         19141
# runtime             0
# vote_average      296
# vote_count        296
# dtype: int64

# %%
#find out how many movies have 0 vote_average and 0 vote_count simultaneously.
num = 0
for var in nums_dtype.T:
  if nums_dtype['vote_average'][var] == 0 and nums_dtype['vote_count'][var] == 0:
    num += 1

print(num)
# Out:
# 296

# %% [markdown]
# Previously, we asked a question: why there are so many movies whose vote average is 0?
#
# There are 296 movies whose vote average is 0, and 296 movies who haven't been voted at all. Is there relationship between these two variables? The answer is yes, 296 of the movies with 0 vote average have not been voted at all!

# %% [markdown]
# Now we finished the most basic statistics.

# %% [markdown]
# ---
#
# # Analysis
#
# In this part, first we want to ask some questions about our data:

# %% [markdown]
# 1. Is there relationship between budget, popularity, revenue, runtime, vote_average ad vote_count?

# %%
# Calculate the complete  correlation matrix
nums_dtype.corr()
# Out:
#                 budget  popularity  ...  vote_average  vote_count
# budget        1.000000    0.529820  ...      0.046481    0.617514
# popularity    0.529820    1.000000  ...      0.127210    0.676700
# revenue       0.728866    0.616657  ...      0.102301    0.804315
# runtime       0.186219    0.126253  ...      0.171339    0.173533
# vote_average  0.046481    0.127210  ...      1.000000    0.174234
# vote_count    0.617514    0.676700  ...      0.174234    1.000000
#
# [6 rows x 6 columns]

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12, 12))
sb.heatmap(nums_dtype.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")

# %%
# Draw pairs of variables against one another
sb.pairplot(data = nums_dtype)

# %% [markdown]
# In the analysis above, we find something quite surprising:
# - The relationship coefficient between `budget` and `popularity` is 0.53, it means that for an "expensive" movie, people might not like it.
# - The relationship coefficient between `popularity` and `revenue` is higher, which is 0.62, it means "popularity" **does not** always bring you high `revenue`.
# - The relationship coefficient between `budget` and `revenue` is 0.73. There is a linear relation between them. Therefore, in general, it can be said that the more you put in, the more you gain.
# - Meanwhile, `runtime` has a relatively low relationship coefficient with all other variables. This tells us `runtime` is not very important to both audience and the producer. A good movie does not depend on its running time!
# - Interestingly, there is a positive relation between `vote_count` and `budget`, `vote_count`, `revenue`. We think `vote_count` shows how much attention the audiences paid to the movie. Thus the relationship shows that the more "expensive" the movie is, the more people care about it. However, `vote_average` has no significant relationship with any of the variables.

# %% [markdown]
# > **Conclusion:**  If we judge the goodness of the movie based on `popularity` and `vote_average`, we can find that goodness doesn't depend on the `budget`, `runtime` and `revenue`. The more money you put into the movie, the more people will be attract. However, it doesn't change the quality of the movie.

# %% [markdown]
# 2. Is there any information about the category like language, company and country?

# %%
movies.head()
# Out:
#       id  movieId  ... vote_average vote_count
# 0    862        1  ...          7.9      13855
# 1   8844        2  ...          7.2       8108
# 2  15602        3  ...          6.5        242
# 3  31357        4  ...          6.4         90
# 4  11862        5  ...          6.2        484
#
# [5 rows x 14 columns]

# %%
print("DataTypes of movies dataset: ", movies.dtypes)
print("Shape of movies dataset: ", movies.shape)
# Out:
# DataTypes of movies dataset:  id                        int64
# movieId                   int64
# title                    object
# genres                   object
# overview                 object
# original_language        object
# budget                    int64
# popularity              float64
# production_companies     object
# production_countries     object
# revenue                   int64
# runtime                   int64
# vote_average            float64
# vote_count                int64
# dtype: object
# Shape of movies dataset:  (26513, 14)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26513 entries, 0 to 26716
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26513 non-null  int64
#  1   movieId               26513 non-null  int64
#  2   title                 26513 non-null  object
#  3   genres                26513 non-null  object
#  4   overview              26438 non-null  object
#  5   original_language     26513 non-null  object
#  6   budget                26513 non-null  int64
#  7   popularity            26513 non-null  float64
#  8   production_companies  26513 non-null  object
#  9   production_countries  26513 non-null  object
#  10  revenue               26513 non-null  int64
#  11  runtime               26513 non-null  int64
#  12  vote_average          26513 non-null  float64
#  13  vote_count            26513 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 4.3+ MB

# %%
# Languages in the Dataset
print("Number of Languages :", len(movies["original_language"].unique()))

# number of movies in each language
print(movies["original_language"].value_counts())
# Out:
# Number of Languages : 89
# en    19577
# fr     1546
# ja      823
# it      584
# de      576
#       ...
# se        1
# uz        1
# rw        1
# lo        1
# tg        1
# Name: original_language, Length: 89, dtype: int64

# %% [markdown]
# When we analyzing the companies and countries, we found that each movie is made by multiple companies and countries. First, we will find out which companies and countries are there.

# %%
companies_str = movies['production_companies']

company = []
for var in companies_str:
  if var != []:
    li = list(var.split('\', \''))
    li[0] = li[0][2:]
    li[-1] = li[-1][:-2]

    for i in li:
      if i not in company and i != '':
        company.append(i)


print(company)
print(len(company))
# Out:
# ['Pixar', 'TriStar Pictures', 'Interscope Communications', 'Teitler Film', 'Sony Pictures', 'Lancaster Gate', 'Warner Bros. Pictures', '20th Century Fox', 'Touchstone Pictures', 'Sandollar Productions', 'Regency Enterprises', 'Forward Pass', 'Worldwide', 'Paramount', 'Mirage Enterprises', 'Constellation Entertainment', 'Mont Blanc Entertainment GmbH', 'Scott Rudin Productions', 'Walt Disney Pictures', 'Painted Fence Productions', 'SHATTERED PRODUCTIONS', 'Universal Pictures', 'Imperial Entertainment', 'Signature Entertainment', 'Eon Productions', 'United Artists', 'Columbia Pictures', 'Castle Rock Entertainment', 'Wildwood Enterprises', 'Enigma Pictures', 'Amblin Entertainment', 'Amblimation', 'Cinergi Pictures Entertainment', 'Hollywood Pictures', 'Le Studio Canal+', 'Laurence Mark Productions', 'Metro-Goldwyn-Mayer', 'Carolco Pictures', 'Syalis DA', 'Légende Entreprises', 'De Fina-Cappa', 'Miramax', 'A Band Apart', 'Morgan Creek Productions', 'Jersey Films', 'New Regency Pictures', 'Dino De Laurentiis Company', 'Silver Pictures', 'Evansgideon/Lazar', 'Canal+', 'Donner/Shuler-Donner Productions', 'Caravan Pictures', 'Intial Productions', 'Lumière Pictures', 'New Line Cinema', 'BBC Films', 'Victoires Productions', 'Constellation Productions', 'Claudie Ossard Productions', 'Eurimages\', "Club d\'Investissement Média", \'Canal+ España', 'Studio Image', 'Cofimage 4', 'Cofimage 5', 'Constellation', 'Elías Querejeta Producciones Cinematográficas S.L.', 'France 3 Cinéma', 'MEDIA Programme of the European Union', 'Ossane', 'Phoenix Images', 'PROCIREP', 'Tele München Fernseh Produktionsgesellschaft (TMG)', 'CNC', 'TVE', 'Alpha Films', 'La Sept Cinéma', 'UGC', 'Shanghai Film Studios', 'Don Simpson/Jerry Bruckheimer Films', 'Via Rosa Productions', 'Atlas Entertainment', 'Classico', 'Iwerks Entertainment', 'Kennedy Miller Productions', 'European Co-production Fund', 'StudioCanal', 'Cinéa', 'Euston Films', 'Freeway Films', 'Orsans Productions', 'PolyGram Filmed Entertainment', 'Havoc', 'Working Title Films', 'Sony New Technologies', 'Dualstar Productions', 'Orr & Cruickshank', 'Rysher Entertainment', 'Alpine Pty Limited', 'Distant Horizon', 'Mayfair Entertainment International', 'British Screen', 'Underworld Entertainment', 'Threshold Entertainment', 'The Rank Organisation', 'Juno Pix', 'Cecchi Gori Pictures', 'Walt Disney Animation Studios', 'Alliance Communications Corporation', 'Bad Hat Harry Productions', 'Blue Parrot Productions', 'PM Entertainment Group', 'Magnolia Pictures', 'CiBy 2000', 'Melenny Productions', 'Téléfilm Canada', 'Egg Pictures', 'Penta Film', 'Esterno Mediterraneo Film', 'Blue Dahlia Productions', 'K2 Two', 'The Kennedy/Marshall Company', 'The Charlie Mopic Company', 'Ivory Way Productions', 'Island Pictures', 'Weasel Productions', '3 Arts Entertainment', 'Motion Picture Corporation of America', 'Les Films Flam', 'Renn Productions', 'TF1 Films Production', 'Los Hooligans Productions', 'Dimension Films', 'Castleberg Productions', 'Lions Gate Films', 'Trimark Pictures', 'TF1', 'Les Films 13', 'Fuji Eight Company Ltd.', 'Allegro Films', 'Fries Film Group', 'Super Ecran', 'Triumph Films', 'The Movie Network', 'ZDF', 'Bluehorse Films', 'Ciak Filmproduktion', 'I.R.I.B. Channel 2', 'Ferdos Films', 'Bergen Film', 'Bard Entertainments', 'NPS Televisie', 'BET Pictures', 'United Image Entertainme', 'Playhouse International Pictures', 'Samuel Goldwyn Company', 'Largo Entertainment', 'Scott Free Productions', 'Joe Wizan/Todd Black', 'Addis Wechsler Pictures', 'NFH Films', 'Woods Entertainment', 'WCG Entertainment Productions', 'The Mark Gordon Company', 'Midwinter Films', 'Kasso Productions', 'Les Productions Lazennec', 'Channel Four Films', 'BBC', 'CBC', 'Cinemax Reel Life', 'InPictures', 'Lafayette Films', 'WDR', 'Boyle-Taylor Productions', 'Gracie Films', 'Indian Paintbrush', 'Spelling Films', 'Brillstein-Grey Entertainment', 'Robert Simonds Productions', 'Malpaso Productions', 'Jim Henson Productions', 'The Jim Henson Compan ...
# 17532

# %%
countries_str = movies['production_countries']

country = []
for var in countries_str:
  if var != []:
    li = list(var.split('\', \''))
    li[0] = li[0][2:]
    li[-1] = li[-1][:-2]

    for i in li:
      if i not in country and i != '':
        country.append(i)


print(country)
print(len(country))
# Out:
# ['United States of America', 'Germany', 'United Kingdom', 'France', 'Italy', 'Spain', 'China', 'Australia', 'South Africa', 'Canada', 'Switzerland', 'Belgium', 'Japan', 'Iran', 'Netherlands', 'Hong Kong', 'Tunisia', 'Ireland', 'Dominican Republic', 'Croatia', 'Russia', 'Macedonia', 'Austria', 'Taiwan', 'New Zealand', 'Mexico', 'Poland', 'Peru', 'Cuba', 'Liechtenstein', 'Denmark', 'Portugal', 'Finland', 'Sweden', 'Argentina', 'Iceland', 'South Korea', 'Bulgaria', 'Czech Republic', 'Hungary', 'Serbia', 'Yugoslavia', 'India', 'Brazil', 'Greece', 'Congo', 'Cameroon', 'Senegal', 'Burkina Faso', 'Romania', 'Philippines', 'Vietnam', 'Norway', 'Chile', 'Soviet Union', 'Bahamas', 'Kazakhstan', 'Georgia', 'Ukraine', 'Luxembourg', 'Morocco', 'Botswana', 'Aruba', 'Turkey', 'Israel', 'Lebanon', 'Bhutan', 'Thailand', 'Jamaica', 'Cambodia', 'Ecuador', 'Egypt', 'Indonesia', 'Kenya', 'Kuwait', 'Nepal', 'Saudi Arabia', 'Tanzania', 'Holy See', 'St. Pierre and Miquelon', 'Haiti', 'Cote D\'Ivoire", \'Burkina Faso', 'Namibia', 'Colombia', 'Czechoslovakia', 'Uruguay', 'Bosnia and Herzegovina', 'Slovenia', 'Libyan Arab Jamahiriya', 'Trinidad and Tobago', 'Algeria', 'Puerto Rico', 'Jordan', 'Latvia', 'East Germany', 'Belarus', 'Singapore', 'Cote D\'Ivoire", \'France', 'Afghanistan', 'Malta', 'Panama', 'Zimbabwe', 'Tajikistan', 'Uzbekistan', 'Martinique', 'Ghana', 'Armenia', 'Malaysia', 'Mongolia', 'Bolivia', 'Monaco', 'Iraq', 'Slovakia', 'Nicaragua', 'Venezuela', 'Rwanda', 'Palestinian Territory', 'Chad', 'Paraguay', 'Qatar', 'Estonia', 'Albania', 'Mali', 'Lithuania', 'United Arab Emirates', 'Azerbaijan', 'Cayman Islands', 'Liberia', 'Angola', 'Costa Rica', 'Antarctica', 'Uganda', 'Mauritania', 'Serbia and Montenegro', 'Bangladesh', 'Pakistan', 'Syrian Arab Republic', 'Kyrgyz Republic', 'North Korea', 'Ethiopia', 'Myanmar', 'New Caledonia', 'Guatemala', 'Somalia', 'Guadaloupe', 'Sri Lanka', 'Papua New Guinea', 'Cyprus', 'Nigeria', 'Australia\', "Lao People\'s Democratic Republic", \'Thailand', 'Greenland', 'Montenegro', 'Macao']
# 153

# %% [markdown]
# Over the 1762 movies, 1402 of them are made by companies. 1664 of them are made in some countries. It is possible that others are made by individual or group.

# %%
genre_str = movies['genres']

genres = []
for var in genre_str:
  if var != []:
    li = list(var.split('\', \''))
    li[0] = li[0][2:]
    li[-1] = li[-1][:-2]

    for i in li:
      if i not in genres and i != '':
        genres.append(i)


print(genres)
print(len(genres))
# Out:
# ['Animation', 'Adventure', 'Family', 'Comedy', 'Fantasy', 'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror', 'History', 'Science Fiction', 'Mystery', 'War', 'Music', 'Documentary', 'Western', 'TV Movie']
# 19

# %%
Fantasy = []
Action = []
Adventure = []
Horror = []
Thriller = []
Mystery = []
ScienceFiction = []
Crime = []
Family = []
Animation = []
Comedy = []
Drama = []
Music = []
Romance = []
History = []
Western = []
War = []
TV_Movie = []
Documentary = []

genre_name = ['Action', 'Adventure', 'Horror', 'Thriller', 'Mystery', 'Crime', 'Family', 'Animation', 'Comedy', 'Drama', 'Music', 'Romance', 'History', 'Western', 'War', 'Documentary']

# %% [markdown]
# ### Regression
# If I am the producer, what I consider most should be revenue. So in this part, we are going to predict the revenue using other virables.
#
# We are not going to focus on it. Doing the regression is just for fun.

# %%
revenue	= pd.DataFrame(movies['revenue'])
budget = pd.DataFrame(movies['budget'])
popularity = pd.DataFrame(movies['popularity'])
runtime	= pd.DataFrame(movies['runtime'])
vote_average = pd.DataFrame(movies['vote_average'])
vote_count = pd.DataFrame(movies['vote_count'])

# %% [markdown]
# Firstly, we predict the revenue by budget

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(budget, revenue, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (RMSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (RMSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [660185.60498828]
# Coefficients of Regression 	: a =  [[2.57013388]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5276715553819014
# Mean Squared Error (RMSE) 	: 2754614344628002.5
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5440436374332165
# Mean Squared Error (RMSE) 	: 2179688558990590.0

# %%
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
# Predict Total values corresponding to HP Train
total_train_pred = linreg.predict(X_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.scatter(X_train, y_train_pred, color = "r")
plt.show()

# %% [markdown]
# That is not bad, but we want to predict better.

# %%
X = pd.DataFrame(movies[['budget', 'popularity', 'runtime', 'vote_average', 'vote_count']])
y = pd.DataFrame(movies['revenue'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(budget, revenue, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Import train_test_split from sklearn
from sklearn.model_selection import train_test_split

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Check the sample sizes
print("Train Set :", y_train.shape, X_train.shape)
print("Test Set  :", y_test.shape, X_test.shape)
# Out:
# Train Set : (19884, 1) (19884, 5)
# Test Set  : (6629, 1) (6629, 5)

# %%
# Summary Statistics for Response
y_train.describe()
# Out:
#             revenue
# count  1.988400e+04
# mean   1.686444e+07
# std    7.181482e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.573480e+05
# max    2.187464e+09

# %%
# Summary Statistics for Predictors
X_train.describe()
# Out:
#              budget    popularity       runtime  vote_average    vote_count
# count  1.988400e+04  19884.000000  19884.000000  19884.000000  19884.000000
# mean   6.470177e+06      7.439531     98.812060      6.215258    387.611899
# std    2.126033e+07      7.231331     24.426396      1.160432   1349.060335
# min    0.000000e+00      0.600000      1.000000      0.000000      0.000000
# 25%    0.000000e+00      3.637500     88.000000      5.700000     15.000000
# 50%    0.000000e+00      6.134000     97.000000      6.400000     44.000000
# 75%    1.000000e+06      8.961250    109.000000      6.900000    174.000000
# max    9.653130e+08    145.168000    300.000000     10.000000  28829.000000

# %%
# Draw the distribution of Response
f, axes = plt.subplots(1, 3, figsize=(24, 6))
sb.boxplot(data = y_train, orient = "h", ax = axes[0])
sb.histplot(data = y_train, bins=30, ax = axes[1])
sb.violinplot(data = y_train, orient = "h", ax = axes[2])

# %%
# Import LinearRegression model from Scikit-Learn
from sklearn.linear_model import LinearRegression


# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"])
# Out:
# Intercept of Regression 	: b =  [-1031356.10464609]
# Coefficients of Regression 	: a =  [[ 1.22797378e+00  5.77110539e+05  5.59366128e+03 -9.80861691e+05
#    2.88968034e+04]]
#      Predictors   Coefficients
# 0        budget       1.227974
# 1    popularity  577110.538770
# 2       runtime    5593.661283
# 3  vote_average -980861.690775
# 4    vote_count   28896.803417

# %%
# Predict the Total values from Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# %%
# Import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (RMSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (RMSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7292346939152243
# Mean Squared Error (RMSE) 	: 1396366282813339.0
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7484242669205808
# Mean Squared Error (RMSE) 	: 1711597799515201.0

# %% [markdown]
# It shows that in general, we can predict the revenue. However, most of the movies are around the origin so that it might not so efficient.

# %% [markdown]
# # Recommendation System without machine learning

# %%
movies.head()
# Out:
#       id  movieId  ... vote_average vote_count
# 0    862        1  ...          7.9      13855
# 1   8844        2  ...          7.2       8108
# 2  15602        3  ...          6.5        242
# 3  31357        4  ...          6.4         90
# 4  11862        5  ...          6.2        484
#
# [5 rows x 14 columns]

# %%
print(company)
print(country)
print(genres)
# Out:
# ['Pixar', 'TriStar Pictures', 'Interscope Communications', 'Teitler Film', 'Sony Pictures', 'Lancaster Gate', 'Warner Bros. Pictures', '20th Century Fox', 'Touchstone Pictures', 'Sandollar Productions', 'Regency Enterprises', 'Forward Pass', 'Worldwide', 'Paramount', 'Mirage Enterprises', 'Constellation Entertainment', 'Mont Blanc Entertainment GmbH', 'Scott Rudin Productions', 'Walt Disney Pictures', 'Painted Fence Productions', 'SHATTERED PRODUCTIONS', 'Universal Pictures', 'Imperial Entertainment', 'Signature Entertainment', 'Eon Productions', 'United Artists', 'Columbia Pictures', 'Castle Rock Entertainment', 'Wildwood Enterprises', 'Enigma Pictures', 'Amblin Entertainment', 'Amblimation', 'Cinergi Pictures Entertainment', 'Hollywood Pictures', 'Le Studio Canal+', 'Laurence Mark Productions', 'Metro-Goldwyn-Mayer', 'Carolco Pictures', 'Syalis DA', 'Légende Entreprises', 'De Fina-Cappa', 'Miramax', 'A Band Apart', 'Morgan Creek Productions', 'Jersey Films', 'New Regency Pictures', 'Dino De Laurentiis Company', 'Silver Pictures', 'Evansgideon/Lazar', 'Canal+', 'Donner/Shuler-Donner Productions', 'Caravan Pictures', 'Intial Productions', 'Lumière Pictures', 'New Line Cinema', 'BBC Films', 'Victoires Productions', 'Constellation Productions', 'Claudie Ossard Productions', 'Eurimages\', "Club d\'Investissement Média", \'Canal+ España', 'Studio Image', 'Cofimage 4', 'Cofimage 5', 'Constellation', 'Elías Querejeta Producciones Cinematográficas S.L.', 'France 3 Cinéma', 'MEDIA Programme of the European Union', 'Ossane', 'Phoenix Images', 'PROCIREP', 'Tele München Fernseh Produktionsgesellschaft (TMG)', 'CNC', 'TVE', 'Alpha Films', 'La Sept Cinéma', 'UGC', 'Shanghai Film Studios', 'Don Simpson/Jerry Bruckheimer Films', 'Via Rosa Productions', 'Atlas Entertainment', 'Classico', 'Iwerks Entertainment', 'Kennedy Miller Productions', 'European Co-production Fund', 'StudioCanal', 'Cinéa', 'Euston Films', 'Freeway Films', 'Orsans Productions', 'PolyGram Filmed Entertainment', 'Havoc', 'Working Title Films', 'Sony New Technologies', 'Dualstar Productions', 'Orr & Cruickshank', 'Rysher Entertainment', 'Alpine Pty Limited', 'Distant Horizon', 'Mayfair Entertainment International', 'British Screen', 'Underworld Entertainment', 'Threshold Entertainment', 'The Rank Organisation', 'Juno Pix', 'Cecchi Gori Pictures', 'Walt Disney Animation Studios', 'Alliance Communications Corporation', 'Bad Hat Harry Productions', 'Blue Parrot Productions', 'PM Entertainment Group', 'Magnolia Pictures', 'CiBy 2000', 'Melenny Productions', 'Téléfilm Canada', 'Egg Pictures', 'Penta Film', 'Esterno Mediterraneo Film', 'Blue Dahlia Productions', 'K2 Two', 'The Kennedy/Marshall Company', 'The Charlie Mopic Company', 'Ivory Way Productions', 'Island Pictures', 'Weasel Productions', '3 Arts Entertainment', 'Motion Picture Corporation of America', 'Les Films Flam', 'Renn Productions', 'TF1 Films Production', 'Los Hooligans Productions', 'Dimension Films', 'Castleberg Productions', 'Lions Gate Films', 'Trimark Pictures', 'TF1', 'Les Films 13', 'Fuji Eight Company Ltd.', 'Allegro Films', 'Fries Film Group', 'Super Ecran', 'Triumph Films', 'The Movie Network', 'ZDF', 'Bluehorse Films', 'Ciak Filmproduktion', 'I.R.I.B. Channel 2', 'Ferdos Films', 'Bergen Film', 'Bard Entertainments', 'NPS Televisie', 'BET Pictures', 'United Image Entertainme', 'Playhouse International Pictures', 'Samuel Goldwyn Company', 'Largo Entertainment', 'Scott Free Productions', 'Joe Wizan/Todd Black', 'Addis Wechsler Pictures', 'NFH Films', 'Woods Entertainment', 'WCG Entertainment Productions', 'The Mark Gordon Company', 'Midwinter Films', 'Kasso Productions', 'Les Productions Lazennec', 'Channel Four Films', 'BBC', 'CBC', 'Cinemax Reel Life', 'InPictures', 'Lafayette Films', 'WDR', 'Boyle-Taylor Productions', 'Gracie Films', 'Indian Paintbrush', 'Spelling Films', 'Brillstein-Grey Entertainment', 'Robert Simonds Productions', 'Malpaso Productions', 'Jim Henson Productions', 'The Jim Henson Compan ...
# ['United States of America', 'Germany', 'United Kingdom', 'France', 'Italy', 'Spain', 'China', 'Australia', 'South Africa', 'Canada', 'Switzerland', 'Belgium', 'Japan', 'Iran', 'Netherlands', 'Hong Kong', 'Tunisia', 'Ireland', 'Dominican Republic', 'Croatia', 'Russia', 'Macedonia', 'Austria', 'Taiwan', 'New Zealand', 'Mexico', 'Poland', 'Peru', 'Cuba', 'Liechtenstein', 'Denmark', 'Portugal', 'Finland', 'Sweden', 'Argentina', 'Iceland', 'South Korea', 'Bulgaria', 'Czech Republic', 'Hungary', 'Serbia', 'Yugoslavia', 'India', 'Brazil', 'Greece', 'Congo', 'Cameroon', 'Senegal', 'Burkina Faso', 'Romania', 'Philippines', 'Vietnam', 'Norway', 'Chile', 'Soviet Union', 'Bahamas', 'Kazakhstan', 'Georgia', 'Ukraine', 'Luxembourg', 'Morocco', 'Botswana', 'Aruba', 'Turkey', 'Israel', 'Lebanon', 'Bhutan', 'Thailand', 'Jamaica', 'Cambodia', 'Ecuador', 'Egypt', 'Indonesia', 'Kenya', 'Kuwait', 'Nepal', 'Saudi Arabia', 'Tanzania', 'Holy See', 'St. Pierre and Miquelon', 'Haiti', 'Cote D\'Ivoire", \'Burkina Faso', 'Namibia', 'Colombia', 'Czechoslovakia', 'Uruguay', 'Bosnia and Herzegovina', 'Slovenia', 'Libyan Arab Jamahiriya', 'Trinidad and Tobago', 'Algeria', 'Puerto Rico', 'Jordan', 'Latvia', 'East Germany', 'Belarus', 'Singapore', 'Cote D\'Ivoire", \'France', 'Afghanistan', 'Malta', 'Panama', 'Zimbabwe', 'Tajikistan', 'Uzbekistan', 'Martinique', 'Ghana', 'Armenia', 'Malaysia', 'Mongolia', 'Bolivia', 'Monaco', 'Iraq', 'Slovakia', 'Nicaragua', 'Venezuela', 'Rwanda', 'Palestinian Territory', 'Chad', 'Paraguay', 'Qatar', 'Estonia', 'Albania', 'Mali', 'Lithuania', 'United Arab Emirates', 'Azerbaijan', 'Cayman Islands', 'Liberia', 'Angola', 'Costa Rica', 'Antarctica', 'Uganda', 'Mauritania', 'Serbia and Montenegro', 'Bangladesh', 'Pakistan', 'Syrian Arab Republic', 'Kyrgyz Republic', 'North Korea', 'Ethiopia', 'Myanmar', 'New Caledonia', 'Guatemala', 'Somalia', 'Guadaloupe', 'Sri Lanka', 'Papua New Guinea', 'Cyprus', 'Nigeria', 'Australia\', "Lao People\'s Democratic Republic", \'Thailand', 'Greenland', 'Montenegro', 'Macao']
# ['Animation', 'Adventure', 'Family', 'Comedy', 'Fantasy', 'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror', 'History', 'Science Fiction', 'Mystery', 'War', 'Music', 'Documentary', 'Western', 'TV Movie']

# %% [markdown]
# The idea of this recommendation system is to find out movies with most common genres, ordering them by popularity and average vote.

# %%
# Reverse mapping of indices and movie titles
indices = pd.Series(movies.index, index=movies['title']).drop_duplicates()
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Military Academy               26712
# Fire, Ice & Canned Beer        26713
# The Pirates                    26714
# The Rose of the Rascal         26715
# Innocence                      26716
# Length: 26513, dtype: int64

# %%
#get the genres
fav_genre = []
fav = 'Toy Story'
i = indices[fav]
print(i)
var = movies['genres'][i]
if var != []:
  li = list(var.split('\', \''))
  li[0] = li[0][2:]
  li[-1] = li[-1][:-2]

  for i in li:
    fav_genre.append(i)

fav_genre
# Out:
# 0
# ['Animation', 'Adventure', 'Family', 'Comedy']

# %%
#find out index of movies with more than 3/4 of the genres same with the favourite movie
recommend = []
for i in movies.index:
  test_genre = []
  var = movies['genres'][i]
  if var != []:
    li = list(var.split('\', \''))
    li[0] = li[0][2:]
    li[-1] = li[-1][:-2]

    for j in li:
      test_genre.append(j)
  
  if len(set(fav_genre) & set(test_genre)) >= (3*len(fav_genre)/4):
    recommend.append(i)

recommend[:10]
# Out:
# [0, 12, 47, 53, 86, 105, 235, 254, 263, 309]

# %%
recom_data = movies[movies.index.isin(recommend)]
recom_data.head(10)
# Out:
#         id  movieId  ... vote_average vote_count
# 0      862        1  ...          7.9      13855
# 12   21032       13  ...          7.3       1535
# 47   10530       48  ...          7.0       4422
# 53   26441       54  ...          5.6        128
# 86   17414       87  ...          5.3        158
# 105  10874      107  ...          6.6        248
# 235  15789      239  ...          6.9       1239
# 254  37108      258  ...          4.7        112
# 263  11008      267  ...          6.3        502
# 309  22586      313  ...          6.6        725
#
# [10 rows x 14 columns]

# %% [markdown]
# ---
#
# # Approach I: Content-based Recommendation System
#
# We do not have a quantitative metric to judge our machine's performance so this will have to be done qualitatively. In order to do so, we will follow two steps:
# 1. First, we use **TfidfVectorizer** function from **scikit-learn**, which transforms text to feature vectors that can be used as input to estimator.
# 2. After that we use sklearn's **linear_kernel** to calculate the similarity between two movies.

# %% [markdown]
# ### Using 'overview' as a recommendation feature.
#
# Are there certain words that feature more often in Movie Overviews? We will attempt to figure this out using a word-cloud visualization.

# %%
# Import new libraries
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# Create a wordcloud of the movie overviews
movies['overview'] = movies['overview'].fillna("").astype('str')
overview_corpus = ' '.join(movies['overview'])
overview_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='black', height=2000, width=4000).generate(overview_corpus)

# Plot the wordcloud
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# We can recognize that there are a lot of movie franchises in this dataset, as evidenced by words like *life, find, family*... are among the most commonly occuring words. Now we start building our content-based recommender.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer(min_df=3,  max_features=None, 
                               strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
                               ngram_range=(1, 3), stop_words = 'english')
movies['overview'] = movies['overview'].fillna("").astype('str')

# %%
# Fitting the TF-IDF on the 'overview' text
overview_tfv_matrix = tfv.fit_transform(movies['overview'])
overview_tfv_matrix.shape
# Out:
# (26513, 45850)

# %%
from sklearn.metrics.pairwise import linear_kernel

overview_sim = linear_kernel(overview_tfv_matrix, overview_tfv_matrix)
overview_sim[1]
# Out:
# array([0.018483  , 1.        , 0.04202759, ..., 0.        , 0.        ,
#        0.        ])

# %%
# Reverse mapping of indices and movie titles
titles = movies.title
indices = pd.Series(movies.index, index=movies['title']).drop_duplicates()
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Military Academy               26712
# Fire, Ice & Canned Beer        26713
# The Pirates                    26714
# The Rose of the Rascal         26715
# Innocence                      26716
# Length: 26513, dtype: int64

# %%
def get_recommendations(title, cosine_sim):
    try:
        idx = indices[title]
    except:
        print("Film (%s) does not exist in the dataset" % title)
        return
    
    if type(idx) != np.dtype('int64') and len(idx) > 1:
        print("There are several films called (%s)" % title)
        print("Their indices are: ", movies[movies.title == title].index)
        idx = sorted(idx, key=lambda x: movies.iloc[x].popularity, reverse=True)
        idx = idx[0]
        print("For recommendation, I will take the most popular one with id ", movies.iloc[idx].id)

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]
    return titles.iloc[movie_indices]

# %%
# Testing our overview-based recommendation system with the movie 'Avatar'
get_recommendations('Avatar', overview_sim)
# Out:
# 18148                   The Painting Sellers
# 21497                              Onnenpeli
# 25914      The Lumière Brothers' First Films
# 13555                      Flatfoot in Egypt
# 25026    Workers Leaving the Lumière Factory
# 18167                          The Way South
# 1781                   Passion in the Desert
# 21816                    My Piece of the Pie
# 16601         Chronicle of the Years of Fire
# 25396                                 My Way
# Name: title, dtype: object

# %%
# Testing our overview-based recommendation system with the movie 'Toy Story'
get_recommendations('Toy Story', overview_sim)
# Out:
# 15221                                    Toy Story 3
# 2986                                     Toy Story 2
# 1874                                  Child's Play 2
# 17036                                      Group Sex
# 10249                         The 40 Year Old Virgin
# 23344                    Andy Hardy's Blonde Trouble
# 485                                           Malice
# 23963                                      Small Fry
# 13846                            The Gang's All Here
# 7594     The First $20 Million Is Always the Hardest
# Name: title, dtype: object

# %%
# Testing our overview-based recommendation system with the movie 'The Matrix'
get_recommendations('The Matrix', overview_sim)
# Out:
# 6742         Holy Matrimony
# 17837               11 x 14
# 21581       Pillow of Death
# 10227               Un Flic
# 14031    Death of a Cyclist
# 40              Richard III
# 15787             Rogue Cop
# 22606             Blood Out
# 10395       Evelyn Prentice
# 18981              Radio On
# Name: title, dtype: object

# %% [markdown]
# There is an problem when getting recommendations for the movie 'Toy Story' (a movie for children), movie 'Group Sex' (an adult movie) is recommended. This is definitely not good, so we will try again with the 'genres' the feature.

# %% [markdown]
# ### Using 'genres' as a recommendation feature.
#
# As we mentioned earlier, we do not have a quantitative metric to judge our machine's performance. Therefore, we will build another recommneder suggest movies that are the most similar to a particular movie based on its genres.

# %%
from ast import literal_eval
movies['genres_str'] = movies['genres'].apply(literal_eval).apply(lambda x: ' '.join(x))

# %%
# Fitting the TF-IDF on the 'genres' text
genres_tfv_matrix = tfv.fit_transform(movies['genres_str'])
genres_tfv_matrix.shape
# Out:
# (26513, 1130)

# %%
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity
genres_sim = linear_kernel(genres_tfv_matrix, genres_tfv_matrix)
genres_sim[1]
# Out:
# array([0.09669655, 1.        , 0.        , ..., 0.06154791, 0.        ,
#        0.08395207])

# %%
# Testing our genres-based recommendation system with the seminal movie 'Avatar'
get_recommendations('Avatar', genres_sim)
# Out:
# 97                        Heidi Fleiss: Hollywood Madam
# 106                                             Catwalk
# 134                    From the Journals of Jean Seberg
# 159                                               Crumb
# 189                                            The Show
# 203                                            Unzipped
# 242                                         Hoop Dreams
# 358    The Wonderful, Horrible Life of Leni Riefenstahl
# 393                                     Frank and Ollie
# 399    Brother Minister: The Assassination of Malcolm X
# Name: title, dtype: object

# %%
# Testing our genres-based recommendation system with the seminal movie 'Toy Story'
get_recommendations('Toy Story', genres_sim)
# Out:
# 18795        The Pirates! In an Adventure with Scientists!
# 12                                                   Balto
# 859      The Land Before Time III: The Time of the Grea...
# 1915                                    The Black Cauldron
# 4378                                  The Land Before Time
# 5806                            The Wild Thornberrys Movie
# 10878               Pinocchio and the Emperor of the Night
# 11741                         The Adventures of Mark Twain
# 14275                           The Pebble and the Penguin
# 20842       Lego Batman: The Movie - DC Super Heroes Unite
# Name: title, dtype: object

# %%
# Testing our genres-based recommendation system with the seminal movie 'The Matrix'
get_recommendations('The Matrix', genres_sim)
# Out:
# 19445    The Strange Case of the End of Civilization as...
# 21249                                      Murder à la Mod
# 2506                                      Frogs for Snakes
# 3723                                     Cecil B. Demented
# 6640                                             Crimewave
# 10093                                    The Ferpect Crime
# 19609                                          The Octopus
# 20135                                        The Liability
# 23139                                              Caprice
# 11976                                         Shoot 'Em Up
# Name: title, dtype: object

# %% [markdown]
# As you can see, we have lists of recommendation for movies **Avatar**, **Toy Story**, and **The Matrix** from both systems and they are all different. Hence, we conclude the pro and con of using content-based recommendation:
# - **Pros**:
#   - The model does not need any data about other users, since the recommendations are specific to a user.
#   - The model can capture the specific interests of a user, and can recommend niche items that may not popular but still relevant to the user profile
# - **Cons**:
#   - The recommendations is very narrow. For example, if the user like an action movie, the system would never recommend other genres
#   - Our system recommend movies based on a given movie, so the recommendations will be the same to every user, this is not good as each user may have different tastes.

# %% [markdown]
# ---
#
# # Approach II: Collaborative Filtering Recommendation System
#
# The idea of Collaborative Filtering is based on the idea that users similar to me can be used to predict how much I will like a particular product or service those users have experienced but I have not.
#
# For that I will use the **Surprise** library that used extremely powerful algorithms like **Singular Value Decomposition (SVD)** to minimise RMSE (Root Mean Square Error) and give great recommendations.
#
# **Surpsise** is a Python scikit building and analysing recommender systems.

# %%
# Install 'surprise' library, then import essential functions
# !pip install surprise
from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly
from surprise.model_selection import train_test_split

from collections import defaultdict
from surprise.model_selection import KFold
from surprise import KNNWithMeans  #Memory based, Collaborative Based Filtering
from surprise import SVD  #Model Based, Matrix Factorization

from surprise.model_selection import GridSearchCV

from surprise import accuracy
# Out:
# Collecting surprise
#   Downloading https://files.pythonhosted.org/packages/61/de/e5cba8682201fcf9c3719a6fdda95693468ed061945493dea2dd37c5618b/surprise-0.1-py2.py3-none-any.whl
# Collecting scikit-surprise
#   Downloading https://files.pythonhosted.org/packages/97/37/5d334adaf5ddd65da99fc65f6507e0e4599d092ba048f4302fe8775619e8/scikit-surprise-1.1.1.tar.gz (11.8MB)
#      |████████████████████████████████| 11.8MB 8.0MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.0.1)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise->surprise) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp37-cp37m-linux_x86_64.whl size=1617555 sha256=6bcac515c1074d3221bca305c2dcde00c006b2f4847485d09eba80690dfd2276
#   Stored in directory: /root/.cache/pip/wheels/78/9c/3d/41b419c9d2aff5b6e2b4c0fc8d25c538202834058f9ed110d0
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.1 surprise-0.1

# %%
# Get the ratings dataset (from movielens)
ratings = pd.read_csv('ratings.csv')
print(ratings.shape)
ratings.head()
# Out:
# (5000000, 3)
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
# Loads the ratings dataset 
reader = Reader()
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']],reader)
raw_ratings = data.raw_ratings

# A = 75% of the data, B = 25% of the data
threshold = int(.75 * len(raw_ratings))
A_raw_ratings = raw_ratings[:threshold]
B_raw_ratings = raw_ratings[threshold:]

data.raw_ratings = A_raw_ratings # data is not the set A

# %%
# Model based, Matrix Factorization, SVD
print('Grid Search...')
param_grid = {'n_epochs': [5, 10], 
              'lr_all': [0.002, 0.005]}
gs_svd = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=3)
gs_svd.fit(data) # data is A raw ratings

# Use the algorithm that yields the best rmse
algo_svd = gs_svd.best_estimator['rmse']
# Out:
# Grid Search...

# %%
# retrain on the whole set A
trainset = data.build_full_trainset()
algo_svd.fit(trainset)

# Compute biased accuracy on A
predictions_A = algo_svd.test(trainset.build_testset())
print('Biased accuracy on A:')
# Compute RMSE, MSE, and MAE
accuracy.rmse(predictions_A)
accuracy.mse(predictions_A)
accuracy.mae(predictions_A)
print()

# Compute unbiased accuracy on B
testset = data.construct_testset(B_raw_ratings)  # testset is now the set B
predictions_B = algo_svd.test(testset)
print('Unbiased accuracy on B:')
# Compute RMSE, MSE, and MAE
accuracy.rmse(predictions_B)
accuracy.mse(predictions_B)
accuracy.mae(predictions_B)
print()
# Out:
# Biased accuracy on A:
# RMSE: 0.7559
# MSE: 0.5713
# MAE:  0.5808
#
# Unbiased accuracy on B:
# RMSE: 0.9420
# MSE: 0.8873
# MAE:  0.7282

# %%
def precision_recall_at_k(predictions, k=10, threshold=3.5):
    """Return precision and recall at k metrics for each user"""

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        # When n_rec_k is 0, Precision is undefined. We here set it to 0.

        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 0

        # Recall@K: Proportion of relevant items that are recommended
        # When n_rel is 0, Recall is undefined. We here set it to 0.

        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 0

    return precisions, recalls


data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], Reader())
kf = KFold(n_splits=5)
cnt = 1

for trainset, testset in kf.split(data):
    algo_svd.fit(trainset)
    predictions = algo_svd.test(testset)
    precisions, recalls = precision_recall_at_k(predictions, k=5, threshold=4)
    
    # Precision and recall can then be averaged over all users
    p = sum(prec for prec in precisions.values()) / len(precisions)
    r = sum(rec for rec in recalls.values()) / len(recalls)

    print("Fold:", cnt)
    print("Precision @k:", p)
    print("Recall @k:", r)
    print("F1-Score:", 2 * (p*r)/(p+r))
    print()
    cnt += 1
# Out:
# Fold: 1
# Precision @k: 0.628888403899285
# Recall @k: 0.24010170174728396
# F1-Score: 0.347523349239984
#
# Fold: 2
# Precision @k: 0.6294901652547393
# Recall @k: 0.24094558614740108
# F1-Score: 0.34849872973853724
#
# Fold: 3
# Precision @k: 0.6308474510488533
# Recall @k: 0.24049407951368892
# F1-Score: 0.34823332007508684
#
# Fold: 4
# Precision @k: 0.6260324483775491
# Recall @k: 0.23861082399021824
# F1-Score: 0.3455254279442176
#
# Fold: 5
# Precision @k: 0.6293608741641858
# Recall @k: 0.24170170113095477
# F1-Score: 0.3492690381266965

# %%
# Train an SVD algorithm on the whole dataset for the hybrid approach
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], Reader())
trainset = data.build_full_trainset()
algo_svd.fit(trainset)

# %%
# Let calculate the estimated rating for user 10 with movie 'Toy Story' 
algo_svd.predict(10, movies.loc[indices['Toy Story'], 'movieId']).est
# Out:
# 3.9884387039192584

# %%
def get_top_n(uid, n=10):
    top_movies = movies.loc[:][['title', 'vote_count', 'vote_average', 'movieId']]
    top_movies['est'] = top_movies['movieId'].apply(lambda x: algo_svd.predict(uid, x).est)
    top_movies = top_movies.sort_values('est', ascending=False).head(n)
    return top_movies

    return top_n

# %%
# Try to get top 10 movies for user 10
get_top_n(10, 10)
# Out:
#                             title  vote_count  vote_average  movieId       est
# 5687            My Father's Glory         193           7.4     5839  4.400522
# 314      The Shawshank Redemption       18731           8.7      318  4.400499
# 7935                A Man Escaped         292           8.0     8684  4.372878
# 4157                       Rififi         305           7.9     4298  4.353859
# 49             The Usual Suspects        7650           8.2       50  4.350213
# 16827       Louis C.K.: Hilarious         185           8.0    86345  4.349887
# 11490                   Seven Up!          70           7.3    50740  4.339843
# 8285                 Sherlock Jr.         543           8.2    25750  4.335741
# 7798   A Matter of Life and Death         222           7.8     8516  4.314959
# 7359            The Wages of Fear         522           8.1     7700  4.311766

# %% [markdown]
# The metrics scores we got are not very high, we looked for other related works on the internet, and they are likely the same as us. A better solution to improve is using a neural network model, we may try this as further work. Also, we conclude the pro and con of using content-based recommendation:
# - **Pros**:
#   - The model can help users discover new interests. In isolation, it may not if know the user is interested in a given item, but model might still recommend it because similar users are interested in that item.
#   - To some extent, the system needs only the feedback matrix to train a matrix factorization model. Thus the system does not need contextual feature.
# - **Cons**:
#   - Cold-start problem:
#     - The predictions of the model for a given (user, item) is the dot product of the corresponding embeddings.
#     - If an item is not seen during the training, the system cannot create an embedding for it and cannot query the model with this item.

# %% [markdown]
# ---
#
# # Approach III: Hybrid Recommendation System
#
# The idea of this approach is: first get top 50 scoring films from the cosine_sim matrix above; then for a particular user, sort them by predicted rating for that user.

# %%
def hybrid(userId, title, number=10):
    try:
        idx = indices[title]
    except:
        print("Film (%s) does not exist in the dataset" % title)
        return
    
    if type(idx) != np.dtype('int64') and len(idx) > 1:
        print("There are several films called (%s)" % title)
        print("Their indices are: ", movies[movies.title == title].index)
        idx = sorted(idx, key=lambda x: movies.iloc[x].popularity, reverse=True)
        idx = idx[0]
        print("For recommendation, I will take the most popular one with id ", movies.iloc[idx].id)

    sim_scores = list(enumerate(genres_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:50]
    movie_indices = [i[0] for i in sim_scores]
    
    top_movies = movies.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'movieId']]
    top_movies['est'] = top_movies['movieId'].apply(lambda x: algo_svd.predict(userId, x).est)
    top_movies = top_movies.sort_values('est', ascending=False).head(number)
    return top_movies

# %%
# Testing our hybrid recommendation system with userId 10 and movie 'Avatar'
hybrid(10, 'Avatar', 10)
# Out:
#                                                  title  ...       est
# 358   The Wonderful, Horrible Life of Leni Riefenstahl  ...  4.139503
# 1126                                    American Dream  ...  4.088626
# 1148                                  Paris Is Burning  ...  4.077095
# 2208              Hands on a Hardbody: The Documentary  ...  4.033576
# 739                    Maya Lin: A Strong Clear Vision  ...  4.009407
# 1566                      Fast, Cheap & Out of Control  ...  4.003471
# 1106                                When We Were Kings  ...  3.989339
# 574                               The Celluloid Closet  ...  3.958348
# 1074                                       Microcosmos  ...  3.949152
# 159                                              Crumb  ...  3.927692
#
# [10 rows x 5 columns]

# %%
# Testing our hybrid recommendation system with userId 10 and movie 'Toy Story'
hybrid(10, 'Toy Story', 10)
# Out:
#                                                title  ...       est
# 6018                              The Black Stallion  ...  3.893322
# 21774                                         Frozen  ...  3.769582
# 18795  The Pirates! In an Adventure with Scientists!  ...  3.700994
# 20832   Oblivion Island: Haruka and the Magic Mirror  ...  3.652407
# 6244                                 Treasure Island  ...  3.642498
# 10878         Pinocchio and the Emperor of the Night  ...  3.602216
# 7816                             Kaena: The Prophecy  ...  3.570541
# 1939                          The Incredible Journey  ...  3.564162
# 1938                      In Search of the Castaways  ...  3.536170
# 15697  Legend of the Guardians: The Owls of Ga'Hoole  ...  3.530731
#
# [10 rows x 5 columns]

# %%
# Testing our hybrid recommendation system with userId 10 and movie 'The Matrix'
hybrid(10, 'The Matrix', 10)
# Out:
#                                                    title  ...       est
# 921                                         The Thin Man  ...  4.186878
# 7446                                  After the Thin Man  ...  4.037759
# 7445                              Shadow of the Thin Man  ...  4.000026
# 4878                                     Murder by Death  ...  3.969510
# 6906                                  A Shot in the Dark  ...  3.928469
# 11368                             It's a Wonderful World  ...  3.817563
# 10093                                  The Ferpect Crime  ...  3.811934
# 5786                                           Deathtrap  ...  3.721926
# 19445  The Strange Case of the End of Civilization as...  ...  3.672725
# 15319                                            Gumshoe  ...  3.672689
#
# [10 rows x 5 columns]
